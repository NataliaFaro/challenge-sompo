# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Sprint2_RiscosAgricolas.csv", sep=";")
df.head()
# Out:
#   data_coleta  hora_utc temp_ins temp_max temp_min  umi_ins  umi_max  umi_min  \
# 0  01/03/2026         0     19,9     21,4     19,9       77       77       69
# 1  01/03/2026       100     18,7     19,9     18,7       82       82       77
# 2  01/03/2026       200     17,9     18,7     17,9       84       84       81
# 3  01/03/2026       300     17,5       18     17,5       87       87       84
# 4  01/03/2026       400     17,4     17,7     17,4       87       87       86
#
#   pressao_ins vel_vento chuva_mm  horas_uso vibracao_motor  proximidade_agua  \
# 0       925,9       0,5        0        339           4,26              1764
# 1       926,3       1,1        0        349           0,77              1116
# 2       926,8       0,5        0        348           0,68               663
# 3       926,5       1,1        0        194           3,41              1993
# 4       926,2       0,6        0        131           3,92               868
#
#    declividade  qtidade_falhas classificacao_risco
# 0           13               4                alto
# 1           10               2               medio
# 2            6               0               medio
# 3           10               3               baixo
# 4            3               8                alto

# %%
#Ver Colunas
df.columns
# Out:
# Index(['data_coleta', 'hora_utc', 'temp_ins', 'temp_max', 'temp_min',
#        'umi_ins', 'umi_max', 'umi_min', 'pressao_ins', 'vel_vento', 'chuva_mm',
#        'horas_uso', 'vibracao_motor', 'proximidade_agua', 'declividade',
#        'qtidade_falhas', 'classificacao_risco'],
#       dtype='object')

# %%
#Informações do DataSet
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   data_coleta          744 non-null    object
#  1   hora_utc             744 non-null    int64
#  2   temp_ins             744 non-null    object
#  3   temp_max             744 non-null    object
#  4   temp_min             744 non-null    object
#  5   umi_ins              744 non-null    int64
#  6   umi_max              744 non-null    int64
#  7   umi_min              744 non-null    int64
#  8   pressao_ins          744 non-null    object
#  9   vel_vento            744 non-null    object
#  10  chuva_mm             744 non-null    object
#  11  horas_uso            744 non-null    int64
#  12  vibracao_motor       744 non-null    object
#  13  proximidade_agua     744 non-null    int64
#  14  declividade          744 non-null    int64
#  15  qtidade_falhas       744 non-null    int64
#  16  classificacao_risco  744 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 98.9+ KB

# %%
# Lista de colunas numéricas

colunas_numericas = [
    "temp_ins",
    "temp_max",
    "temp_min",
    "umi_ins",
    "umi_max",
    "umi_min",
    "pressao_ins",
    "vel_vento",
    "chuva_mm",
    "horas_uso",
    "vibracao_motor",
    "proximidade_agua",
    "declividade",
    "qtidade_falhas"
]

# Converter vírgula para ponto e transformar em float

for col in colunas_numericas:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace(",", ".", regex=False)
    )

    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   data_coleta          744 non-null    object
#  1   hora_utc             744 non-null    int64
#  2   temp_ins             744 non-null    float64
#  3   temp_max             744 non-null    float64
#  4   temp_min             744 non-null    float64
#  5   umi_ins              744 non-null    int64
#  6   umi_max              744 non-null    int64
#  7   umi_min              744 non-null    int64
#  8   pressao_ins          744 non-null    float64
#  9   vel_vento            744 non-null    float64
#  10  chuva_mm             744 non-null    float64
#  11  horas_uso            744 non-null    int64
#  12  vibracao_motor       744 non-null    float64
#  13  proximidade_agua     744 non-null    int64
#  14  declividade          744 non-null    int64
#  15  qtidade_falhas       744 non-null    int64
#  16  classificacao_risco  744 non-null    object
# dtypes: float64(7), int64(8), object(2)
# memory usage: 98.9+ KB

# %%
##HeatMap

plt.figure(figsize=(12,8))

sns.heatmap(
    df[colunas_numericas].corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlação entre Variáveis")
plt.show()
